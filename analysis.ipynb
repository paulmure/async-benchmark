# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')

# %%
df.dtypes
# Out:
# Unnamed: 0       int64
# ThreadCount      int64
# Go             float64
# Rust           float64
# dtype: object

# %%
plt.xlabel('Thread Count')
plt.ylabel('Runtime (seconds)')
plt.title('Async Benchmark')


plt.plot(df.ThreadCount,  df.Go, color='blue', label="Go")
plt.plot(df.ThreadCount, df.Rust, color='orange', label="Rust")

plt.legend()
